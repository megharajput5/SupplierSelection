# %%
import csv
import random
import pandas as pd

# Generate a CSV file with 50000 records
def generate_supplier_data():
    product_types = ["Electronics", "Home Appliances", "Furniture", "Beauty Products"]
    supliers = ["Sup A","Sup B","Sup C"]
    communications = [1,2,3,4,5]
    with open("SupplierData.csv", "w", newline="") as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(["SupplierName", "ProductType", "Quality", "Delivery",
                         "Price", "RepairService", "Reliability", "Communication", "Performance", "Reputation",
                         "Warranty", "Availability"])
        for i in range(50000):
            supplier_name = random.choice(supliers)
            product_type = random.choice(product_types)
            quality = random.choice([1,2,3,4,5])
            time = random.choice([2,4,6,8])
            price = random.randint(10, 1000)
            repair = random.choice([1,0])
            reliability = random.choice([1,2,3,4,5])
            communication = random.choice(communications)
            performance = random.choice([1,2,3,4,5])
            reputation = random.choice([1,2,3,4,5])
            warenty = random.choice([1,0])
            available = random.randint(10, 10000)

            writer.writerow([supplier_name,product_type,quality,time,price,repair,reliability,communication,
            performance,reputation,warenty,available])
    print("SupplierData.csv file has been generated.")
# Generate the CSV file
generate_supplier_data()
pd.read_csv("SupplierData.csv")
# Out:
# SupplierData.csv file has been generated.
#       SupplierName      ProductType  Quality  Delivery  Price  RepairService  \
# 0            Sup A  Beauty Products        3         4    337              1
# 1            Sup A  Beauty Products        2         6    648              1
# 2            Sup B      Electronics        3         8    889              1
# 3            Sup C      Electronics        4         4    314              1
# 4            Sup A  Home Appliances        4         6    605              1
# ...            ...              ...      ...       ...    ...            ...
# 49995        Sup A        Furniture        4         8     10              1
# 49996        Sup A      Electronics        3         6    522              0
# 49997        Sup B      Electronics        2         2    525              0
# 49998        Sup A  Home Appliances        2         6    601              1
# 49999        Sup C  Beauty Products        3         4    947              1
#
# ...

# %%
import pandas as pd
df = pd.read_csv("SupplierData.csv")
df.describe()
# Out:
#             Quality      Delivery         Price  RepairService   Reliability  \
# count  50000.000000  50000.000000  50000.000000   50000.000000  50000.000000
# mean       3.010900      4.991400    504.772560       0.503380      2.999260
# std        1.413811      2.233066    286.080523       0.499994      1.414956
# min        1.000000      2.000000     10.000000       0.000000      1.000000
# 25%        2.000000      2.000000    255.000000       0.000000      2.000000
# 50%        3.000000      4.000000    504.000000       1.000000      3.000000
# 75%        4.000000      6.000000    753.000000       1.000000      4.000000
# max        5.000000      8.000000   1000.000000       1.000000      5.000000
#
#        Communication   Performance    Reputation      Warranty  Availability
# count   50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean        2.989720      2.994520      2.992940      0.501300   5015.826140
# ...
